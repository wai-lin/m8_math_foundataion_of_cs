# %%
import numpy as np


def test_plane(x):
    return 2 * x[0] - x[1] + 3*x[2]


n = 1000
m = 6

a = -1
b = 1

# random points on the plane
x_vals = np.random.uniform(a, b, size=(m, n))

y_vals_exact = test_plane(x_vals)

noise = np.random.normal(0, 0.5, size=y_vals_exact.shape)
y = y_vals_exact + noise

X = np.stack(x_vals, axis=1)

c = np.array([1.0] * m)

max_iters = 10000
alpha = 0.0001
eps = 0.000001

for i in range(max_iters):
    c -= alpha * X.T @ (X @ c - y)
    loss = np.linalg.norm(X @ c - y) ** 2

    step = alpha * X.T @ (X @ c - y)
    if np.linalg.norm(step) < eps:
        break

    print(f"{i}: loss: {loss:.2f}; c = {c}")
# Out:
# 0: loss: 1995.53; c = [1.34294499 0.25303948 1.66556433 0.6333018  0.6161369  0.75691733]
# 1: loss: 997.54; c = [ 1.56080446 -0.21649496  2.10637899  0.40314234  0.38352392  0.56572231]
# 2: loss: 577.26; c = [ 1.69996526 -0.51225844  2.3990873   0.25920343  0.2429377   0.41898929]
# 3: loss: 398.02; c = [ 1.7893558  -0.69897797  2.59396191  0.16955413  0.15823816  0.30837899]
# 4: loss: 320.59; c = [ 1.84710106 -0.81713648  2.72404994  0.11398058  0.10740138  0.22612231]
# 5: loss: 286.70; c = [ 1.88461359 -0.89209702  2.8111251   0.07971945  0.07702766  0.16559379]
# 6: loss: 271.67; c = [ 1.90911702 -0.93977904  2.86956789  0.05873448  0.05898004  0.12142655]
# 7: loss: 264.93; c = [ 1.92520848 -0.97019432  2.90889977  0.04598146  0.04832871  0.08941645]
# 8: loss: 261.87; c = [ 1.93582996 -0.98965249  2.93544124  0.03830527  0.04209504  0.0663463 ]
# 9: loss: 260.47; c = [ 1.9428749  -1.00213896  2.9533991   0.03374012  0.03848518  0.04979615]
# 10: loss: 259.82; c = [ 1.94756887 -1.0101771   2.96558084  0.03106685  0.03642298  0.03796935]
# 11: loss: 259.51; c = [ 1.95070958 -1.0153686   2.97386518  0.02953329  0.03526591  0.02954554]
# 12: loss: 259.37; c = [ 1.95281913 -1.01873285  2.97951281  0.02867829  0.0346325   0.02356227]
# 13: loss: 259.30; c = [ 1.95424105 -1.02092047  2.98337197  0.02822126  0.03429786  0.01932259]
# 14: loss: 259.27; c = [ 1.95520252 -1.02234794  2.98601497  0.027993    0.03413058  0.01632455]
# 15: loss: 259.26; c = [ 1.95585446 -1.02328266  2.98782893  0.02789269  0.03405469  0.01420826]
# 16: loss: 259.25; c = [ 1.95629764 -1.02389686  2.98907643  0.02786108  0.0340269   0.01271668]
# 17: loss: 259.25; c = [ 1.95659957 -1.02430187  2.98993601  0.02786407  0.03402301  0.01166679]
# 18: loss: 259.24; c = [ 1.95680566 -1.02456985  2.99052936  0.02788252  0.03402983  0.01092866]
# 19: loss: 259.24; c = [ 1.95694656 -1.02474777  2.99093963  0.0279061   0.03404045  0.01041024]
# 20: loss: 259.24; c = [ 1.95704304 -1.02486629  2.99122375  0.02792957  0.03405147  0.01004644]
# 21: loss: 259.24; c = [ 1.95710918 -1.02494549  2.9914208   0.02795056  0.03406136  0.00979135]
# 22: loss: 259.24; c = [ 1.95715456 -1.02499858  2.99155765  0.02796824  0.03406962  0.00961261]
# 23: loss: 259.24; c = [ 1.95718574 -1.02503427  2.9916528   0.02798259  0.0340762   0.00948743]
# 24: loss: 259.24; c = [ 1.95720717 -1.02505833  2.99171905  0.02799392  0.0340813   0.00939982]
# 25: loss: 259.24; c = [ 1.9572219  -1.0250746   2.99176521  0.02800271  0.03408516  0.00933852]
# 26: loss: 259.24; c = [ 1.95723204 -1.02508562  2.99179741  0.02800943  0.03408804  0.00929565]
# 27: loss: 259.24; c = [ 1.95723902 -1.02509311  2.99181989  0.02801451  0.03409016  0.00926568]
# 28: loss: 259.24; c = [ 1.95724383 -1.02509821  2.9918356   0.02801831  0.0340917   0.00924474]
# 29: loss: 259.24; c = [ 1.95724714 -1.02510169  2.99184659  0.02802114  0.03409282  0.00923011]
# 30: loss: 259.24; c = [ 1.95724942 -1.02510407  2.99185428  0.02802323  0.03409363  0.00921989]
# 31: loss: 259.24; c = [ 1.95725099 -1.0251057   2.99185966  0.02802477  0.0340942   0.00921275]
# 32: loss: 259.24; c = [ 1.95725207 -1.02510681  2.99186343  0.0280259   0.03409461  0.00920776]
# 33: loss: 259.24; c = [ 1.95725281 -1.02510758  2.99186607  0.02802672  0.0340949   0.00920428]
# 34: loss: 259.24; c = [ 1.95725333 -1.02510811  2.99186792  0.02802732  0.0340951   0.00920185]
# 35: loss: 259.24; c = [ 1.95725368 -1.02510847  2.99186922  0.02802775  0.03409525  0.00920016]
# 36: loss: 259.24; c = [ 1.95725392 -1.02510872  2.99187014  0.02802806  0.03409535  0.00919897]
