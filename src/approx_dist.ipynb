# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
locators = [(100, 20), (50, 10), (20, 5), (10, 2), (5, 1), (80, 16)]
distances = [math.sqrt((loc[0] - 0) ** 2 + (loc[1] - 0) ** 2) for loc in locators]
