# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x):
    return x**2 + 3 / 1 + x**3


a, b = (-2, 3)
n = 10
x_points = np.linspace(a, b, n+1)
y_points = f(x_points)
print("x points:", x_points)
print("y points:", y_points)
# Out:
# x points: [-2.  -1.5 -1.  -0.5  0.   0.5  1.   1.5  2.   2.5  3. ]
# y points: [-1.     1.875  3.     3.125  3.     3.375  5.     8.625 15.    24.875
#  39.   ]

# %%
V = np.zeros((n + 1, n + 1))
for i in range(n + 1):
    for j in range(n + 1):
        V[i][j] = x_points[i] ** j
# V

# %%
c = np.linalg.solve(V, y_points)
c
# Out:
# array([ 3.00000000e+00,  1.42108547e-15,  1.00000000e+00,  1.00000000e+00,
#        -3.03049766e-15,  2.46962944e-15,  1.03127383e-15, -1.08555140e-15,
#         1.75580535e-29,  1.44740187e-16, -2.63163976e-17])

# %%
x_plot = np.linspace(a-1, b+1, 100)
y_func = f(x_plot)
y_plot = sum(c[i] * x_plot**i for i in range(len(c)))

fig, ax = plt.subplots()
ax.plot(x_plot, y_func, color='blue', label='Function f(x)')
ax.plot(x_plot, y_plot, color='green', label='Polynomial')
ax.scatter(x_points, y_points, color='black', label='Points')
ax.legend()
